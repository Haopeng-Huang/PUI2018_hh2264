# %%
import numpy as np
import pylab as pl
from __future__ import print_function
__author__= 'fbb'
import seaborn
from scipy.optimize import curve_fit, minimize

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python2/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
#choose which distribution to use
#distributions = ['pois', 'lnorm', 'chisq', 'cauchy', 'norm', 'binomial']
distributions = ['chisq']

# %%
mymean = 100

# %%
# the chi sq distribution takes the number of degrees of freedom, which luckily is the same as the mean!
df = mymean

# %%
import numpy as np

md = {}
# md is an empty disctionary
md['chisq'] = np.random.chisquare(df, size=100)
# md now is a dictionary with one object: an array by the key 'chisq'
pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python2/lib/python2.7/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 1: Chi sq distribution: df = 100, N=100

# %% [markdown]
# Let numpy calculate what the mean and stdev of this distribution are.

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 99.83, standard deviation: 13.98

# %% [markdown]
# Now let's do it for 100 Chisq distributions.
# We want distributions of different sizes (all integers between 10 and 2000).

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
# mysize = 1000 / (np.array(range(1, 100) + [10]))
# mysize = (np.random.rand(100) * 1000).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
# I am gonna overwrite the disctionary entry created into a nested dictionary 
# the outside dictionary hosts the distributions as dictionary, 
# and each distribution dictionary contains the 100 distribution (arrays of diferent sizes)
md['chisq'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size = n)
    
# save the means for plotting later    

md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# Figure 2: The behavior in the plot falls along with the Central Limit Theorem that the distribution of the means of 100 samples generated from the same parent distribution is normally distributed and the larger the sample zie, the closer its mean will be to the mean of the parent distribution/population ( ~= 100).

# %% [markdown]
# Plot histogram of all sample means:

# %%
allmeans = list(md['chisq']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# Figure 3: The distribution of all sample means is a normal distribution and the number of the sample means that fall closer to the population mean (100) is more than that of the sample means that are far from 100.

# %% [markdown]
# # Normal Distribution

# %%
distributions = ['norm']

# %%
mymean = 100

# %%
import numpy as np

md['norm'] = np.random.normal(loc=100,size=100)
# md now is a dictionary with one object: an array by the key 'norm'
pl.hist(md['norm'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# Figure 4: Normal distribution: mean = 100, N=100

# %% [markdown]
# Let numpy calculate what the mean and stdev of this distribution are.

# %%
print ("Norm mean: %.2f, standard deviation: %.2f"%(md['norm'].mean(), md['norm'].std()))
# Out:
# Norm mean: 99.97, standard deviation: 1.00

# %% [markdown]
# Now let's do it for 100 Normal distributions. We want distributions of different sizes (all integers between 10 and 2000).

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
# mysize = 1000 / (np.array(range(1, 100) + [10]))
# mysize = (np.random.rand(100) * 1000).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['norm'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['norm'][n] = np.random.normal(loc=100, size = n)
    
# save the means for plotting later    

md['norm']['means'] = {}
axnorm_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['norm']:
    if not type(nn) == str:
        md['norm']['means'][nn] = md['norm'][nn].mean()
        #and plot it
        axnorm_mu_n.plot(nn, md['norm']['means'][nn], 'o')
        axnorm_mu_n.set_xlabel('sample size', fontsize=18)
        axnorm_mu_n.set_ylabel('sample mean', fontsize=18)
        axnorm_mu_n.set_title('Normal', fontsize=18)
        axnorm_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# Figure 5: The behavior in the plot falls along with the Central Limit Theorem that the distribution of the means of 100 samples generated from the same parent distribution is normally distributed and the larger the sample zie, the closer its mean will be to the mean of the parent distribution/population ( ~= 100).

# %% [markdown]
# Plot histogram of all sample means:

# %%
allmeans = list(md['norm']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# Figure 6: The distribution of all sample means is a normal distribution and the number of the sample means that fall closer to the population mean (100) is more than that of the sample means that are far from 100.

# %% [markdown]
# # Poisson Distribution

# %%
distributions = ['pois']

# %%
mymean = 100

# %%
import numpy as np

md['pois'] = np.random.poisson(lam=100,size=100)
# md now is a dictionary with one object: an array by the key 'norm'
pl.hist(md['pois'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# Figure 7: Poisson distribution: expectation of interval = 100, N=100

# %% [markdown]
# Let numpy calculate what the mean and stdev of this distribution are.

# %%
print ("Pois mean: %.2f, standard deviation: %.2f"%(md['pois'].mean(), md['pois'].std()))
# Out:
# Pois mean: 100.52, standard deviation: 9.79

# %% [markdown]
# Now let's do it for 100 Poisson distributions. We want distributions of different sizes (all integers between 10 and 2000).

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
# mysize = 1000 / (np.array(range(1, 100) + [10]))
# mysize = (np.random.rand(100) * 1000).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['pois'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['pois'][n] = np.random.poisson(lam=100, size = n)
    
# save the means for plotting later    

md['pois']['means'] = {}
axpois_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['pois']:
    if not type(nn) == str:
        md['pois']['means'][nn] = md['pois'][nn].mean()
        #and plot it
        axpois_mu_n.plot(nn, md['pois']['means'][nn], 'o')
        axpois_mu_n.set_xlabel('sample size', fontsize=18)
        axpois_mu_n.set_ylabel('sample mean', fontsize=18)
        axpois_mu_n.set_title('Poisson', fontsize=18)
        axpois_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# Figure 8: The behavior in the plot falls along with the Central Limit Theorem that the distribution of the means of 100 samples generated from the same parent distribution is normally distributed and the larger the sample zie, the closer its mean will be to the mean of the parent distribution/population ( ~= 100).

# %% [markdown]
# Plot histogram of all sample means:

# %%
allmeans = list(md['pois']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# Figure 8: The distribution of all sample means is a normal distribution and the number of the sample means that fall closer to the population mean (100) is more than that of the sample means that are far from 100.

# %% [markdown]
# # Binomial Distribution

# %%
distributions = ['binomial']

# %%
mymean = 100

# %%
import numpy as np

md['binomial'] = np.random.binomial(n=200,p=0.5,size=100)
# md now is a dictionary with one object: an array by the key 'norm'
pl.hist(md['binomial'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# Figure 9: Binomial distribution: number of trials = 200, probability of success = 0.5, N=100

# %% [markdown]
# Let numpy calculate what the mean and stdev of this distribution are.

# %%
print ("Binomial mean: %.2f, standard deviation: %.2f"%(md['binomial'].mean(), md['binomial'].std()))
# Out:
# Binomial mean: 98.92, standard deviation: 7.49

# %% [markdown]
# Now let's do it for 100 Binomial distributions. We want distributions of different sizes (all integers between 10 and 2000).

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
# mysize = 1000 / (np.array(range(1, 100) + [10]))
# mysize = (np.random.rand(100) * 1000).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['binomial'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['binomial'][n] = np.random.binomial(n=200,p=0.5,size = n)
    
# save the means for plotting later    

md['binomial']['means'] = {}
axbinomial_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['binomial']:
    if not type(nn) == str:
        md['binomial']['means'][nn] = md['binomial'][nn].mean()
        #and plot it
        axbinomial_mu_n.plot(nn, md['binomial']['means'][nn], 'o')
        axbinomial_mu_n.set_xlabel('sample size', fontsize=18)
        axbinomial_mu_n.set_ylabel('sample mean', fontsize=18)
        axbinomial_mu_n.set_title('Binomial', fontsize=18)
        axbinomial_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# Figure 10: The behavior in the plot falls along with the Central Limit Theorem that the distribution of the means of 100 samples generated from the same parent distribution is normally distributed and the larger the sample zie, the closer its mean will be to the mean of the parent distribution/population ( ~= 100).

# %% [markdown]
# Plot histogram of all sample means:

# %%
allmeans = list(md['binomial']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# Figure 11: The distribution of all sample means is a normal distribution and the number of the sample means that fall closer to the population mean (100) is more than that of the sample means that are far from 100.

# %% [markdown]
# # Logistic Distribution

# %%
distributions = ['log']

# %%
mymean = 100

# %%
import numpy as np

md['log'] = np.random.logistic(loc=100,scale=1,size=100)
# md now is a dictionary with one object: an array by the key 'norm'
pl.hist(md['log'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# Figure 12: Logistic distribution: mean = 100, scale = 1, N=100

# %% [markdown]
# Let numpy calculate what the mean and stdev of this distribution are.

# %%
print ("Logistic mean: %.2f, standard deviation: %.2f"%(md['log'].mean(), md['log'].std()))
# Out:
# Logistic mean: 99.98, standard deviation: 1.87

# %% [markdown]
# Now let's do it for 100 Logistic distributions. We want distributions of different sizes (all integers between 10 and 2000).

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
# mysize = 1000 / (np.array(range(1, 100) + [10]))
# mysize = (np.random.rand(100) * 1000).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['log'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['log'][n] = np.random.logistic(loc=100,scale=1,size = n)
    
# save the means for plotting later    

md['log']['means'] = {}
axlog_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['log']:
    if not type(nn) == str:
        md['log']['means'][nn] = md['log'][nn].mean()
        #and plot it
        axlog_mu_n.plot(nn, md['log']['means'][nn], 'o')
        axlog_mu_n.set_xlabel('sample size', fontsize=18)
        axlog_mu_n.set_ylabel('sample mean', fontsize=18)
        axlog_mu_n.set_title('Logistic', fontsize=18)
        axlog_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# Figure 13: The behavior in the plot falls along with the Central Limit Theorem that the distribution of the means of 100 samples generated from the same parent distribution is normally distributed and the larger the sample zie, the closer its mean will be to the mean of the parent distribution/population ( ~= 100).

# %% [markdown]
# Plot histogram of all sample means:

# %%
allmeans = list(md['log']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# Figure 14: The distribution of all sample means is a normal distribution and the number of the sample means that fall closer to the population mean (100) is more than that of the sample means that are far from 100.

# %% [markdown]
# # Distributions of All Sample Means for 5 Distributions

# %%
allmeans = []

allmeans += (list(md['chisq']['means'].values()))
allmeans += (list(md['norm']['means'].values()))
allmeans += (list(md['pois']['means'].values()))
allmeans += (list(md['binomial']['means'].values()))
allmeans += (list(md['log']['means'].values()))

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.title("Histogram of All 5 Distributions of their Sample Means",fontsize = 18)

# %% [markdown]
# Figure 15: The distributions of all sample means is normally distributed and have mean closely equal to the mean of the population distribution (100) given a large enough observation size.

# %% [markdown]
# # Extra Credit:

# %%
allmeans = []

allmeans += (list(md['chisq']['means'].values()))
allmeans += (list(md['norm']['means'].values()))
allmeans += (list(md['pois']['means'].values()))
allmeans += (list(md['binomial']['means'].values()))
allmeans += (list(md['log']['means'].values()))

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.title("Histogram of All 5 Distributions of their Sample Means",fontsize = 18)

# %%
from scipy.stats import norm
from scipy import stats
m,s = stats.norm.fit(allmeans)
pl.hist(allmeans,bins=30,normed=True)
xmin, xmax = plt.xlim()
x = np.linspace(xmin,xmax,100)
y = norm.pdf(x,m,s)
plt.plot(x,y)
plt.show()
